# %% [markdown]
# # Option Chains
#
# Adapted from [ib_async option_chain](https://ib-api-reloaded.github.io/ib_async/notebooks.html).
#
# **BLOCKED on issue #38**: Multi-asset class support (Options, Futures, Forex, Bonds).
#
# ibx is currently stock-only (hardcoded `167=STK`). Options require:
# - SecurityType OPT support in FIX message builders
# - Strike, expiry, put/call, Greeks
# - `reqSecDefOptParams()` in EClient
# - `tick_option_computation` callback wiring
#
# See issue #38 for the full implementation plan.
