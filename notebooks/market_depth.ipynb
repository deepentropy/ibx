# %% [markdown]
# # Market Depth (Order Book)
#
# Adapted from [ib_async market_depth](https://ib-api-reloaded.github.io/ib_async/notebooks.html).
#
# **BLOCKED on issues #31 / #51**: L2/DOM market depth support.
#
# Only L1 (top-of-book bid/ask/last) is implemented. L2 requires:
# - FIX 35=V MarketDataRequest with depth in the Rust engine
# - Incremental depth update parsing (insert/update/delete)
# - `reqMktDepth()` / `cancelMktDepth()` in EClient
# - `update_mkt_depth` / `update_mkt_depth_l2` callback wiring
#
# See issues #31 and #51 for the full implementation plan.
